# %% [markdown]
# ### ResNet18 모델 정의 및 인스턴스 초기화

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os


# ResNet18을 위해 최대한 간단히 수정한 BasicBlock 클래스 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, Identity mapping이 아닌 경우 (입력값 =/= 출력값 dim)
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out


# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False) #conv layer 1개
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1) #basic block 당 conv layer 2개
                                                                            #그게 2개이므로 총 4개
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        #총 16개의 conv layer
        
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)#첫번째 conv 연산에 의해서만 너비와 높이가 줄어들 수 있도록
                                                   #나머지는 stride = 1 로하여 같은 너비와 높이 유지
                                                #filter 개수가 증가할때마다 너비와 높이는 줄어들수 있게 설정
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


# ResNet18 함수 정의
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %% [markdown]
# ### 데이터셋(Dataset) 다운로드 및 불러오기

# %%
import torchvision
import torchvision.transforms as transforms

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
  
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### 환경 설정 및 학습(Training) 함수 정의

# %%
device = 'cuda:1'

net = ResNet18()
net = net.to(device)
# net = torch.nn.DataParallel(net)
cudnn.benchmark = True

learning_rate = 0.1
file_name = 'resnet18_cifar10.pt'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0001)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        benign_outputs = net(inputs)
        loss = criterion(benign_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = benign_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

#learning rate를 바꾸기
def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 100:
        lr /= 10 #1/10 로 줄이기
    if epoch >= 150:
        lr /= 10  #1/10 로 줄이기
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# ### 학습(Training) 진행

# %%
for epoch in range(0, 150):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current benign train accuracy: 0.0859375
# Current benign train loss: 2.372758626937866
#
# Current batch: 100
# Current benign train accuracy: 0.296875
# Current benign train loss: 1.9468672275543213
#
# Current batch: 200
# Current benign train accuracy: 0.3203125
# Current benign train loss: 1.826780915260315
#
# Current batch: 300
# Current benign train accuracy: 0.4453125
# Current benign train loss: 1.5565731525421143
#
# Total benign train accuarcy: 32.01
# Total benign train loss: 752.5413776636124
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 34.28
# Test average loss: 0.018626053309440612
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.3515625
# Current benign train loss: 1.6823360919952393
#
# Current batch: 100
# Current benign train accuracy: 0.4140625
# Current benign train loss: 1.5369478464126587
#
# Current batch: 200
# Current benign train accuracy: 0.3828125
# Current benign train loss: 1.6747404336929321
#
# Current batch: 300
# Current benign train accuracy: 0.3984375
# Current benign train loss: 1.5662755966186523
#
# Total benign train accuarcy: 45.398
# Total benign train loss: 577.3136229515076
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 46.0
# Test average loss: 0.014933376479148865
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.4765625
# Current benign train loss: 1.3247641324996948
#
# Current batch: 100
# Current benign train accuracy: 0.5546875
# Current benign train loss: 1.2972135543823242
#
# Current batch: 200
# Current benign train accuracy: 0.515625
# Current benign train loss: 1.2693597078323364
#
# Current batch: 300
# Current benign train accuracy: 0.5234375
# Current benign train loss: 1.2880027294158936
#
# Total benign train accuarcy: 54.596
# Total benign train loss: 489.77125430107117
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 58.73
# Test average loss: 0.011514945501089096
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.53125
# Current benign train loss: 1.2022559642791748
#
# Current batch: 100
# Current benign train accuracy: 0.59375
# Current benign train loss: 1.221332311630249
#
# Current batch: 200
# Current benign train accuracy: 0.5390625
# Current benign train loss: 1.1976956129074097
#
# Current batch: 300
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.9312731623649597
#
# Total benign train accuarcy: 62.348
# Total benign train loss: 412.03166621923447
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 59.53
# Test average loss: 0.01216271453499794
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.9608146548271179
#
# Current batch: 100
# Current benign train accuracy: 0.6640625
# Current benign train loss: 0.9486345648765564
#
# Current batch: 200
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.8335682153701782
#
# Current batch: 300
# Current benign train accuracy: 0.6796875
# Current benign train loss: 0.8386567234992981
#
# Total benign train accuarcy: 68.132
# Total benign train loss: 350.36595821380615
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 66.89
# Test average loss: 0.009790660262107849
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.8371727466583252
#
# Current batch: 100
# Current benign train accuracy: 0.734375
# Current benign train loss: 0.7630307078361511
#
# Current batch: 200
# Current benign train accuracy: 0.7265625
# Current benign train loss: 0.7540501952171326
#
# Current batch: 300
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5669925808906555
#
# Total benign train accuarcy: 72.492
# Total benign train loss: 303.74257829785347
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 68.36
# Test average loss: 0.00894461812376976
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.7487351298332214
#
# Current batch: 100
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.8185357451438904
#
# Current batch: 200
# Current benign train accuracy: 0.75
# Current benign train loss: 0.6251020431518555
#
# Current batch: 300
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.747880220413208
#
# Total benign train accuarcy: 76.65
# Total benign train loss: 261.83995574712753
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 75.36
# Test average loss: 0.007009279835224151
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.6292093992233276
#
# Current batch: 100
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7059821486473083
#
# Current batch: 200
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6121760010719299
#
# Current batch: 300
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6079459190368652
#
# Total benign train accuarcy: 79.024
# Total benign train loss: 234.6913117468357
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 79.48
# Test average loss: 0.005960847190022468
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.6010109782218933
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5281602740287781
#
# Current batch: 200
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.6977314352989197
#
# Current batch: 300
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.49432650208473206
#
# Total benign train accuarcy: 81.548
# Total benign train loss: 208.83104446530342
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 77.72
# Test average loss: 0.0069158111125230785
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5196395516395569
#
# Current batch: 100
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5164029598236084
#
# Current batch: 200
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5168635249137878
#
# Current batch: 300
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.4682609438896179
#
# Total benign train accuarcy: 83.104
# Total benign train loss: 190.4176323413849
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 81.91
# Test average loss: 0.005409051537513733
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.43536871671676636
#
# Current batch: 100
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4053623378276825
#
# Current batch: 200
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5317010879516602
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4701204299926758
#
# Total benign train accuarcy: 84.564
# Total benign train loss: 174.0801601856947
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 80.5
# Test average loss: 0.006214946764707565
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.875
# Current benign train loss: 0.38425517082214355
#
# Current batch: 100
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.27339401841163635
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4079784154891968
#
# Current batch: 300
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3310496509075165
#
# Total benign train accuarcy: 85.56
# Total benign train loss: 162.70902948081493
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 82.11
# Test average loss: 0.005427882984280586
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.3519327938556671
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4223630428314209
#
# Current batch: 200
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.42814141511917114
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4922531545162201
#
# Total benign train accuarcy: 86.518
# Total benign train loss: 150.75394451618195
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 81.66
# Test average loss: 0.005398937678337097
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.3000536859035492
#
# Current batch: 100
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.24870601296424866
# Current batch: 200
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.3190076947212219
#
# Current batch: 300
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4360516369342804
#
# Total benign train accuarcy: 87.422
# Total benign train loss: 141.26227900385857
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 84.04
# Test average loss: 0.004586342026293278
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.33361300826072693
#
# Current batch: 100
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3446691334247589
#
# Current batch: 200
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.3565326929092407
#
# Current batch: 300
# Current benign train accuracy: 0.875
# Current benign train loss: 0.33458268642425537
#
# Total benign train accuarcy: 88.508
# Total benign train loss: 130.4381532073021
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 85.15
# Test average loss: 0.004593064898252487
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.309892863035202
#
# Current batch: 100
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3253616690635681
#
# Current batch: 200
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.39801380038261414
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4241940975189209
#
# Total benign train accuarcy: 88.91
# Total benign train loss: 124.98202894628048
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 85.6
# Test average loss: 0.004201743195950985
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.2488059401512146
#
# Current batch: 100
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.263753205537796
#
# Current batch: 200
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.3663349449634552
#
# Current batch: 300
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.2563423812389374
#
# Total benign train accuarcy: 89.68
# Total benign train loss: 116.90709510445595
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 86.31
# Test average loss: 0.004333259570598602
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3240138590335846
#
# Current batch: 100
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.30206528306007385
#
# Current batch: 200
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.1978948712348938
#
# Current batch: 300
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3204417824745178
#
# Total benign train accuarcy: 90.188
# Total benign train loss: 110.81409481167793
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 86.59
# Test average loss: 0.004063953663408756
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.33104437589645386
#
# Current batch: 100
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.2551279067993164
#
# Current batch: 200
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.3261842429637909
#
# Current batch: 300
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.24925225973129272
#
# Total benign train accuarcy: 90.672
# Total benign train loss: 104.39671409130096
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 86.18
# Test average loss: 0.00417948247641325
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.27854737639427185
#
# Current batch: 100
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.19526800513267517
#
# Current batch: 200
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3061719834804535
#
# Current batch: 300
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2542380690574646
#
# Total benign train accuarcy: 90.96
# Total benign train loss: 100.12130787968636
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 87.41
# Test average loss: 0.003890840695798397
# Model Saved!
#
# [ Train epoch: 20 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.14292632043361664
#
# Current batch: 100
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.21158170700073242
#
# Current batch: 200
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.23526999354362488
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.12892812490463257
#
# Total benign train accuarcy: 91.486
# Total benign train loss: 95.50090117752552
#
# [ Test epoch: 20 ]
#
# Test accuarcy: 84.7
# Test average loss: 0.004880367150902748
# Model Saved!
#
# [ Train epoch: 21 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.15874534845352173
#
# Current batch: 100
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.2296353131532669
#
# Current batch: 200
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.23250678181648254
#
# Current batch: 300
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.21926957368850708
#
# Total benign train accuarcy: 91.702
# Total benign train loss: 93.16446141898632
#
# [ Test epoch: 21 ]
#
# Test accuarcy: 87.04
# Test average loss: 0.003995893995463848
# Model Saved!
#
# [ Train epoch: 22 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.18081091344356537
#
# Current batch: 100
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.13234256207942963
#
# Current batch: 200
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.2147800326347351
#
# Current batch: 300
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.24347887933254242
#
# Total benign train accuarcy: 92.164
# Total benign train loss: 88.21426741033792
#
# [ Test epoch: 22 ]
#
# Test accuarcy: 85.27
# Test average loss: 0.004743669120967388
# Model Saved!
#
# [ Train epoch: 23 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.23081350326538086
#
# Current batch: 100
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.22995714843273163
#
# Current batch: 200
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.23779836297035217
#
# Current batch: 300
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.20204591751098633
#
# Total benign train accuarcy: 92.344
# Total benign train loss: 85.66456171870232
#
# [ Test epoch: 23 ]
#
# Test accuarcy: 85.52
# Test average loss: 0.004632620404660702
# Model Saved!
#
# [ Train epoch: 24 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2685460150241852
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.12959280610084534
#
# Current batch: 200
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.10159783065319061
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.11824027448892593
#
# Total benign train accuarcy: 92.606
# Total benign train loss: 81.78644835203886
#
# [ Test epoch: 24 ]
#
# Test accuarcy: 87.22
# Test average loss: 0.004233168102800846
# Model Saved!
#
# [ Train epoch: 25 ]
#
# Current batch: 0
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.21351398527622223
#
# Current batch: 100
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.14176444709300995
#
# Current batch: 200
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2885146141052246
#
# Current batch: 300
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.2302626669406891
#
# Total benign train accuarcy: 92.794
# Total benign train loss: 80.46670247614384
#
# [ Test epoch: 25 ]
#
# Test accuarcy: 86.68
# Test average loss: 0.004494097481667995
# Model Saved!
#
# [ Train epoch: 26 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.19934605062007904
#
# Current batch: 100
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.1998414695262909
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.05258645489811897
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.13535788655281067
# Total benign train accuarcy: 93.09
# Total benign train loss: 76.47285750880837
#
# [ Test epoch: 26 ]
#
# Test accuarcy: 87.86
# Test average loss: 0.004017341405898333
# Model Saved!
#
# [ Train epoch: 27 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.16903628408908844
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.14120014011859894
#
# Current batch: 200
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.23545478284358978
#
# Current batch: 300
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.2854923605918884
#
# Total benign train accuarcy: 93.434
# Total benign train loss: 72.86000822484493
#
# [ Test epoch: 27 ]
#
# Test accuarcy: 87.32
# Test average loss: 0.004171158963441848
# Model Saved!
#
# [ Train epoch: 28 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.16964229941368103
#
# Current batch: 100
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.19349052011966705
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10649149119853973
#
# Current batch: 300
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.19149647653102875
#
# Total benign train accuarcy: 93.27
# Total benign train loss: 74.47996312007308
#
# [ Test epoch: 28 ]
#
# Test accuarcy: 86.3
# Test average loss: 0.004547609694302082
# Model Saved!
#
# [ Train epoch: 29 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.2159087359905243
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.12093505263328552
#
# Current batch: 200
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.17367695271968842
#
# Current batch: 300
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.3584864139556885
#
# Total benign train accuarcy: 93.81
# Total benign train loss: 70.50517882034183
#
# [ Test epoch: 29 ]
#
# Test accuarcy: 88.34
# Test average loss: 0.0037459771409630777
# Model Saved!
#
# [ Train epoch: 30 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11193442344665527
#
# Current batch: 100
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.12703964114189148
#
# Current batch: 200
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.11337950825691223
#
# Current batch: 300
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1835114061832428
#
# Total benign train accuarcy: 94.022
# Total benign train loss: 67.89546749740839
#
# [ Test epoch: 30 ]
#
# Test accuarcy: 88.88
# Test average loss: 0.0035288786381483077
# Model Saved!
#
# [ Train epoch: 31 ]
#
# Current batch: 0
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.17535485327243805
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.14377866685390472
#
# Current batch: 200
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.1936587393283844
#
# Current batch: 300
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.12115579843521118
#
# Total benign train accuarcy: 94.006
# Total benign train loss: 66.27574089169502
#
# [ Test epoch: 31 ]
#
# Test accuarcy: 88.44
# Test average loss: 0.003671091452240944
# Model Saved!
#
# [ Train epoch: 32 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.16959568858146667
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.12652385234832764
#
# Current batch: 200
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.17267724871635437
#
# Current batch: 300
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.17461232841014862
#
# Total benign train accuarcy: 94.322
# Total benign train loss: 63.35288255289197
#
# [ Test epoch: 32 ]
#
# Test accuarcy: 89.25
# Test average loss: 0.0036642857819795607
# Model Saved!
#
# [ Train epoch: 33 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.12055062502622604
#
# Current batch: 100
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1263006329536438
#
# Current batch: 200
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.17414943873882294
#
# Current batch: 300
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.19115771353244781
#
# Total benign train accuarcy: 94.378
# Total benign train loss: 63.189526963979006
#
# [ Test epoch: 33 ]
#
# Test accuarcy: 90.21
# Test average loss: 0.0032314904361963274
# Model Saved!
#
# [ Train epoch: 34 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1194017305970192
#
# Current batch: 100
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.07608344405889511
#
# Current batch: 200
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.11140772700309753
#
# Current batch: 300
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.23255302011966705
#
# Total benign train accuarcy: 94.358
# Total benign train loss: 63.48798107728362
#
# [ Test epoch: 34 ]
#
# Test accuarcy: 88.18
# Test average loss: 0.003920624208450317
# Model Saved!
#
# [ Train epoch: 35 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.08920887857675552
#
# Current batch: 100
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.1583731472492218
#
# Current batch: 200
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.22422702610492706
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1415911614894867
#
# Total benign train accuarcy: 94.584
# Total benign train loss: 60.299031499773264
#
# [ Test epoch: 35 ]
#
# Test accuarcy: 90.15
# Test average loss: 0.0032591093838214872
# Model Saved!
#
# [ Train epoch: 36 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.16944482922554016
#
# Current batch: 100
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.2047272026538849
#
# Current batch: 200
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.0908319354057312
#
# Current batch: 300
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2191513627767563
#
# Total benign train accuarcy: 94.682
# Total benign train loss: 59.72018422558904
#
# [ Test epoch: 36 ]
#
# Test accuarcy: 89.22
# Test average loss: 0.0037669864013791083
# Model Saved!
#
# [ Train epoch: 37 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.21089962124824524
#
# Current batch: 100
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.14470571279525757
#
# Current batch: 200
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11845125257968903
#
# Current batch: 300
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.1815076470375061
#
# Total benign train accuarcy: 94.772
# Total benign train loss: 58.78945895284414
#
# [ Test epoch: 37 ]
#
# Test accuarcy: 87.97
# Test average loss: 0.004141681571304798
# Model Saved!
#
# [ Train epoch: 38 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.16858318448066711
#
# Current batch: 100
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.09625537693500519
#
# Current batch: 200
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.18385355174541473
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.081383116543293
#
# Total benign train accuarcy: 94.772
# Total benign train loss: 58.37305624783039
#
# [ Test epoch: 38 ]
#
# Test accuarcy: 86.67
# Test average loss: 0.004645518909394741
# Model Saved!
#
# [ Train epoch: 39 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.15183013677597046
#
# Current batch: 100
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.14616860449314117
#
# Current batch: 200
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1119680404663086
#
# Current batch: 300
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.12531223893165588
#
# Total benign train accuarcy: 94.982
# Total benign train loss: 55.79369028657675
#
# [ Test epoch: 39 ]
#
# Test accuarcy: 86.86
# Test average loss: 0.004450593188405037
# Model Saved!
#
# [ Train epoch: 40 ]
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.16463196277618408
#
# Current batch: 100
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.11939972639083862
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.07268824428319931
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1375098079442978
#
# Total benign train accuarcy: 95.044
# Total benign train loss: 55.30249237269163
#
# [ Test epoch: 40 ]
#
# Test accuarcy: 89.53
# Test average loss: 0.0035521504499018194
# Model Saved!
#
# [ Train epoch: 41 ]
#
# Current batch: 0
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.2517731785774231
#
# Current batch: 100
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.1668943464756012
#
# Current batch: 200
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.24546948075294495
#
# Current batch: 300
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.24457429349422455
#
# Total benign train accuarcy: 95.116
# Total benign train loss: 54.71951446682215
#
# [ Test epoch: 41 ]
#
# Test accuarcy: 88.36
# Test average loss: 0.004038296057283878
# Model Saved!
#
# [ Train epoch: 42 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.08937336504459381
#
# Current batch: 100
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.15334433317184448
#
# Current batch: 200
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.20315232872962952
#
# Current batch: 300
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.16378724575042725
#
# Total benign train accuarcy: 95.158
# Total benign train loss: 53.62111543491483
#
# [ Test epoch: 42 ]
#
# Test accuarcy: 88.05
# Test average loss: 0.004148198740184307
# Model Saved!
#
# [ Train epoch: 43 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.1114441454410553
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10533277690410614
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08205309510231018
#
# Current batch: 300
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.15936744213104248
#
# Total benign train accuarcy: 95.344
# Total benign train loss: 52.70030344650149
#
# [ Test epoch: 43 ]
#
# Test accuarcy: 88.63
# Test average loss: 0.0037600514091551303
# Model Saved!
#
# [ Train epoch: 44 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.07874520868062973
#
# Current batch: 100
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.12609165906906128
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.05126268044114113
#
# Current batch: 300
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.17961746454238892
#
# Total benign train accuarcy: 95.266
# Total benign train loss: 51.73189156129956
#
# [ Test epoch: 44 ]
#
# Test accuarcy: 88.7
# Test average loss: 0.003823329736292362
# Model Saved!
#
# [ Train epoch: 45 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.13365253806114197
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.12966662645339966
#
# Current batch: 200
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.2226608395576477
#
# Current batch: 300
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.08282171934843063
#
# Total benign train accuarcy: 95.472
# Total benign train loss: 50.07098524644971
#
# [ Test epoch: 45 ]
#
# Test accuarcy: 89.41
# Test average loss: 0.0036786757305264472
# Model Saved!
#
# [ Train epoch: 46 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.078001007437706
#
# Current batch: 100
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.14709404110908508
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.07414287328720093
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.105289027094841
#
# Total benign train accuarcy: 95.482
# Total benign train loss: 50.0504456423223
#
# [ Test epoch: 46 ]
#
# Test accuarcy: 87.03
# Test average loss: 0.004690496681630611
# Model Saved!
#
# [ Train epoch: 47 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.0928041934967041
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.12422742694616318
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08419255167245865
#
# Current batch: 300
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.20121221244335175
#
# Total benign train accuarcy: 95.324
# Total benign train loss: 51.58069038391113
#
# [ Test epoch: 47 ]
#
# Test accuarcy: 88.97
# Test average loss: 0.0040191786363720896
# Model Saved!
#
# [ Train epoch: 48 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.06213654950261116
#
# Current batch: 100
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.1846059262752533
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.07946398854255676
#
# Current batch: 300
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.17709267139434814
#
# Total benign train accuarcy: 95.534
# Total benign train loss: 49.23933341726661
#
# [ Test epoch: 48 ]
#
# Test accuarcy: 89.51
# Test average loss: 0.003724107421934605
# Model Saved!
#
# [ Train epoch: 49 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10943372547626495
#
# Current batch: 100
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1060531884431839
#
# Current batch: 200
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.16931842267513275
#
# Current batch: 300
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.10154475271701813
#
# Total benign train accuarcy: 95.584
# Total benign train loss: 49.26020271144807
#
# [ Test epoch: 49 ]
#
# Test accuarcy: 89.37
# Test average loss: 0.0036575003281235693
# Model Saved!
#
# [ Train epoch: 50 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.09812641888856888
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.07730818539857864
#
# Current batch: 200
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.2406008392572403
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10378680378198624
#
# Total benign train accuarcy: 95.592
# Total benign train loss: 48.541030138731
#
# [ Test epoch: 50 ]
#
# Test accuarcy: 90.14
# Test average loss: 0.003232430547475815
# Model Saved!
#
# [ Train epoch: 51 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.06566380709409714
#
# Current batch: 100
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.17326363921165466
#
# Current batch: 200
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.16170798242092133
#
# Current batch: 300
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.10314139723777771
#
# Total benign train accuarcy: 95.7
# Total benign train loss: 48.008175641298294
#
# [ Test epoch: 51 ]
#
# Test accuarcy: 89.0
# Test average loss: 0.003822076301276684
# Model Saved!
#
# [ Train epoch: 52 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.12999746203422546
#
# Current batch: 100
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.16472378373146057
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.0715961754322052
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1145617738366127
#
# Total benign train accuarcy: 95.86
# Total benign train loss: 46.48895873501897
#
# [ Test epoch: 52 ]
#
# Test accuarcy: 88.61
# Test average loss: 0.004289994241297245
# Model Saved!
#
# [ Train epoch: 53 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09540645778179169
#
# Current batch: 100
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.06630219519138336
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.0779825747013092
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09235793352127075
#
# Total benign train accuarcy: 95.864
# Total benign train loss: 45.35042480751872
#
# [ Test epoch: 53 ]
#
# Test accuarcy: 89.9
# Test average loss: 0.0034796714305877687
# Model Saved!
#
# [ Train epoch: 54 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11806207150220871
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09970135241746902
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.05794654041528702
#
# Current batch: 300
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.15716679394245148
#
# Total benign train accuarcy: 95.838
# Total benign train loss: 46.84988447278738
#
# [ Test epoch: 54 ]
#
# Test accuarcy: 88.9
# Test average loss: 0.00379784282296896
# Model Saved!
#
# [ Train epoch: 55 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11231979727745056
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.08836426585912704
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10176342725753784
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11876605451107025
#
# Total benign train accuarcy: 95.836
# Total benign train loss: 45.784410793334246
#
# [ Test epoch: 55 ]
#
# Test accuarcy: 88.62
# Test average loss: 0.0039263859421014785
# Model Saved!
#
# [ Train epoch: 56 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.05505382642149925
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08037611842155457
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.07464458048343658
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09639632701873779
#
# Total benign train accuarcy: 95.94
# Total benign train loss: 45.1010257974267
#
# [ Test epoch: 56 ]
#
# Test accuarcy: 88.24
# Test average loss: 0.004024236060678959
# Model Saved!
#
# [ Train epoch: 57 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11760580539703369
#
# Current batch: 100
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.11551087349653244
#
# Current batch: 200
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.07402752339839935
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10397927463054657
#
# Total benign train accuarcy: 95.994
# Total benign train loss: 44.94810215383768
#
# [ Test epoch: 57 ]
#
# Test accuarcy: 89.44
# Test average loss: 0.003776713819056749
# Model Saved!
#
# [ Train epoch: 58 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.12629306316375732
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.09418594837188721
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.06034637987613678
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10221108794212341
#
# Total benign train accuarcy: 96.08
# Total benign train loss: 43.19171505048871
#
# [ Test epoch: 58 ]
#
# Test accuarcy: 87.56
# Test average loss: 0.004639508441090584
# Model Saved!
#
# [ Train epoch: 59 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.13564598560333252
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.08798692375421524
#
# Current batch: 200
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1248667985200882
#
# Current batch: 300
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.17365264892578125
#
# Total benign train accuarcy: 95.916
# Total benign train loss: 45.73609318211675
#
# [ Test epoch: 59 ]
#
# Test accuarcy: 89.94
# Test average loss: 0.0033591158106923103
# Model Saved!
#
# [ Train epoch: 60 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1185218095779419
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11345625668764114
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.08534309267997742
#
# Current batch: 300
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.09054510295391083
#
# Total benign train accuarcy: 96.306
# Total benign train loss: 41.984224896878004
#
# [ Test epoch: 60 ]
#
# Test accuarcy: 89.18
# Test average loss: 0.003673759025335312
# Model Saved!
#
# [ Train epoch: 61 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.06328172236680984
#
# Current batch: 100
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.12446437776088715
#
# Current batch: 200
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.1374284327030182
#
# Current batch: 300
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10187137126922607
#
# Total benign train accuarcy: 96.102
# Total benign train loss: 43.950655007734895
#
# [ Test epoch: 61 ]
#
# Test accuarcy: 84.68
# Test average loss: 0.005730619199573994
# Model Saved!
#
# [ Train epoch: 62 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.06962067633867264
#
# Current batch: 100
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.042578890919685364
#
# Current batch: 200
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.0970345139503479
#
# Current batch: 300
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.16258551180362701
#
# Total benign train accuarcy: 96.224
# Total benign train loss: 41.76920496113598
#
# [ Test epoch: 62 ]
#
# Test accuarcy: 90.01
# Test average loss: 0.003761816996335983
# Model Saved!
#
# [ Train epoch: 63 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10774606466293335
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.06894788891077042
#
# Current batch: 200
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.11736337095499039
#
# Current batch: 300
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.17716313898563385
#
# Total benign train accuarcy: 96.036
# Total benign train loss: 44.94503068551421
#
# [ Test epoch: 63 ]
#
# Test accuarcy: 89.59
# Test average loss: 0.003687274506688118
# Model Saved!
#
# [ Train epoch: 64 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.06411124020814896
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.07911024242639542
#
# Current batch: 200
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.19915035367012024
#
# Current batch: 300
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.18316783010959625
#
# Total benign train accuarcy: 96.214
# Total benign train loss: 41.99578411132097
#
# [ Test epoch: 64 ]
#
# Test accuarcy: 90.4
# Test average loss: 0.00348558484390378
# Model Saved!
#
# [ Train epoch: 65 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09654770791530609
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.058561187237501144
#
# Current batch: 200
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09488582611083984
#
# Current batch: 300
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.11762712895870209
#
# Total benign train accuarcy: 96.252
# Total benign train loss: 41.788786517456174
#
# [ Test epoch: 65 ]
#
# Test accuarcy: 90.31
# Test average loss: 0.0034652574896812437
# Model Saved!
#
# [ Train epoch: 66 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.10753435641527176
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.13548336923122406
#
# Current batch: 200
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.2040461301803589
# Current batch: 300
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.12354256957769394
#
# Total benign train accuarcy: 96.464
# Total benign train loss: 40.43944067880511
#
# [ Test epoch: 66 ]
#
# Test accuarcy: 88.69
# Test average loss: 0.003928896562755108
# Model Saved!
#
# [ Train epoch: 67 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.1944863498210907
#
# Current batch: 100
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.042012594640254974
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09157036244869232
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.09848862886428833
#
# Total benign train accuarcy: 96.298
# Total benign train loss: 42.10191021859646
#
# [ Test epoch: 67 ]
#
# Test accuarcy: 89.8
# Test average loss: 0.0037421243615448473
# Model Saved!
#
# [ Train epoch: 68 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.09150102734565735
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.07454303652048111
#
# Current batch: 200
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.1794206202030182
#
# Current batch: 300
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.14507733285427094
#
# Total benign train accuarcy: 96.298
# Total benign train loss: 41.03147156536579
#
# [ Test epoch: 68 ]
#
# Test accuarcy: 88.21
# Test average loss: 0.004439470225572586
# Model Saved!
#
# [ Train epoch: 69 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10274085402488708
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09083028882741928
#
# Current batch: 200
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08902493119239807
#
# Current batch: 300
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1602640450000763
#
# Total benign train accuarcy: 96.376
# Total benign train loss: 40.88776294887066
#
# [ Test epoch: 69 ]
#
# Test accuarcy: 89.97
# Test average loss: 0.0038277405269443988
# Model Saved!
#
# [ Train epoch: 70 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.1701911985874176
#
# Current batch: 100
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.16383816301822662
#
# Current batch: 200
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.16030777990818024
#
# Current batch: 300
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.0730481669306755
#
# Total benign train accuarcy: 96.32
# Total benign train loss: 40.955308420583606
#
# [ Test epoch: 70 ]
#
# Test accuarcy: 89.34
# Test average loss: 0.003795536017417908
# Model Saved!
#
# [ Train epoch: 71 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.10517421364784241
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.07642638683319092
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.0273912213742733
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.09879155457019806
#
# Total benign train accuarcy: 96.238
# Total benign train loss: 41.591376481577754
#
# [ Test epoch: 71 ]
#
# Test accuarcy: 89.83
# Test average loss: 0.003600697758793831
# Model Saved!
#
# [ Train epoch: 72 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.11714942753314972
#
# Current batch: 100
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.0927334874868393
#
# Current batch: 200
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.16548879444599152
#
# Current batch: 300
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.11187735944986343
#
# Total benign train accuarcy: 96.324
# Total benign train loss: 41.67614883184433
#
# [ Test epoch: 72 ]
#
# Test accuarcy: 90.36
# Test average loss: 0.003392697761952877
# Model Saved!
#
# [ Train epoch: 73 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.12755121290683746
#
# Current batch: 100
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.0625733882188797
#
# Current batch: 200
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.16529631614685059
#
# Current batch: 300
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.18007953464984894
#
# Total benign train accuarcy: 96.336
# Total benign train loss: 40.333615116775036
#
# [ Test epoch: 73 ]
#
# Test accuarcy: 89.34
# Test average loss: 0.003882818403840065
# Model Saved!
#
# [ Train epoch: 74 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11053014546632767
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.06857878714799881
#
# Current batch: 200
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.04918699339032173
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.025601495057344437
#
# Total benign train accuarcy: 96.336
# Total benign train loss: 41.290644684806466
#
# [ Test epoch: 74 ]
#
# Test accuarcy: 90.13
# Test average loss: 0.003563947805762291
# Model Saved!
#
# [ Train epoch: 75 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.10837472975254059
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.07181345671415329
#
# Current batch: 200
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.054712362587451935
#
# Current batch: 300
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.1261916607618332
#
# Total benign train accuarcy: 96.426
# Total benign train loss: 40.008109545335174
#
# [ Test epoch: 75 ]
#
# Test accuarcy: 89.61
# Test average loss: 0.003827557481825352
# Model Saved!
#
# [ Train epoch: 76 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.0757233276963234
#
# Current batch: 100
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.17738482356071472
#
# Current batch: 200
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.13540807366371155
#
# Current batch: 300
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.20373639464378357
#
# Total benign train accuarcy: 96.382
# Total benign train loss: 40.37385208904743
#
# [ Test epoch: 76 ]
#
# Test accuarcy: 90.11
# Test average loss: 0.003392478112131357
# Model Saved!
#
# [ Train epoch: 77 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.10053139179944992
#
# Current batch: 100
# Current benign train accuracy: 0.9765625
# ...
# Test average loss: 0.0023165764112025498
# Model Saved!
#
# [ Train epoch: 124 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.002970512956380844
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0018726363778114319
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0008760690689086914
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0012105032801628113
#
# Total benign train accuarcy: 99.95
# Total benign train loss: 1.1433702737558633
#
# [ Test epoch: 124 ]
#
# Test accuarcy: 94.49
# Test average loss: 0.0023173442915081976
# Model Saved!
#
# [ Train epoch: 125 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0005020126700401306
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00513855367898941
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0028266720473766327
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.001551356166601181
#
# Total benign train accuarcy: 99.97
# Total benign train loss: 0.9532269574701786
#
# [ Test epoch: 125 ]
#
# Test accuarcy: 94.4
# Test average loss: 0.0023050262827426196
# Model Saved!
#
# [ Train epoch: 126 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.004533149302005768
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0005138292908668518
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0005914121866226196
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0014874115586280823
#
# Total benign train accuarcy: 99.968
# Total benign train loss: 0.9948924481868744
#
# [ Test epoch: 126 ]
#
# Test accuarcy: 94.39
# Test average loss: 0.0023055564548820255
# Model Saved!
#
# [ Train epoch: 127 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0006111040711402893
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0014548785984516144
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0007646083831787109
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0010991357266902924
#
# Total benign train accuarcy: 99.976
# Total benign train loss: 0.8557312212651595
#
# [ Test epoch: 127 ]
#
# Test accuarcy: 94.53
# Test average loss: 0.0022829022616147996
# Model Saved!
#
# [ Train epoch: 128 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0016036629676818848
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0008549466729164124
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0008414238691329956
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0036463886499404907
#
# Total benign train accuarcy: 99.978
# Total benign train loss: 0.8759569302201271
#
# [ Test epoch: 128 ]
#
# Test accuarcy: 94.61
# Test average loss: 0.002301387843862176
# Model Saved!
#
# [ Train epoch: 129 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0009262487292289734
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0015865787863731384
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0004149824380874634
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0016994401812553406
#
# Total benign train accuarcy: 99.968
# Total benign train loss: 0.8392472456907853
#
# [ Test epoch: 129 ]
#
# Test accuarcy: 94.54
# Test average loss: 0.002306460417062044
# Model Saved!
#
# [ Train epoch: 130 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0008597299456596375
#
# Current batch: 100
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.007255092263221741
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0009462907910346985
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.003382377326488495
#
# Total benign train accuarcy: 99.966
# Total benign train loss: 0.8074921428924426
#
# [ Test epoch: 130 ]
#
# Test accuarcy: 94.43
# Test average loss: 0.002312189557775855
# Model Saved!
#
# [ Train epoch: 131 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0014788731932640076
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.006187867373228073
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0011494755744934082
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.002270471304655075
#
# Total benign train accuarcy: 99.974
# Total benign train loss: 0.7897752069402486
#
# [ Test epoch: 131 ]
#
# Test accuarcy: 94.46
# Test average loss: 0.002350066356360912
# Model Saved!
#
# [ Train epoch: 132 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0007954128086566925
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0007971413433551788
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.004095979034900665
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0010079704225063324
#
# Total benign train accuarcy: 99.98
# Total benign train loss: 0.7236709117423743
#
# [ Test epoch: 132 ]
#
# Test accuarcy: 94.43
# Test average loss: 0.002333636314794421
# Model Saved!
#
# [ Train epoch: 133 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0011162608861923218
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0005166083574295044
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00036306679248809814
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0004734247922897339
#
# Total benign train accuarcy: 99.978
# Total benign train loss: 0.740147965028882
#
# [ Test epoch: 133 ]
#
# Test accuarcy: 94.36
# Test average loss: 0.002331472597271204
# Model Saved!
#
# [ Train epoch: 134 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0010045245289802551
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0015066489577293396
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.000988110899925232
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.003355119377374649
#
# Total benign train accuarcy: 99.986
# Total benign train loss: 0.6549968063773122
#
# [ Test epoch: 134 ]
#
# Test accuarcy: 94.57
# Test average loss: 0.0023108897380530835
# Model Saved!
#
# [ Train epoch: 135 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0011737868189811707
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0035854950547218323
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.000792086124420166
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0023938044905662537
#
# Total benign train accuarcy: 99.988
# Total benign train loss: 0.6513148564845324
#
# [ Test epoch: 135 ]
#
# Test accuarcy: 94.41
# Test average loss: 0.0023215621512383223
# Model Saved!
#
# [ Train epoch: 136 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.013709060847759247
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0017527304589748383
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0013681203126907349
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0013180449604988098
#
# Total benign train accuarcy: 99.976
# Total benign train loss: 0.7159793190658092
#
# [ Test epoch: 136 ]
#
# Test accuarcy: 94.51
# Test average loss: 0.0023066611532121897
# Model Saved!
#
# [ Train epoch: 137 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0025651752948760986
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0009740628302097321
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0010745599865913391
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0007753893733024597
#
# Total benign train accuarcy: 99.98
# Total benign train loss: 0.7099032316473313
#
# [ Test epoch: 137 ]
#
# Test accuarcy: 94.53
# Test average loss: 0.0022796456258744003
# Model Saved!
#
# [ Train epoch: 138 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0008305273950099945
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00043154507875442505
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0016808584332466125
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0007688775658607483
#
# Total benign train accuarcy: 99.974
# Total benign train loss: 0.6770990352961235
#
# [ Test epoch: 138 ]
#
# Test accuarcy: 94.53
# Test average loss: 0.0023352464146912098
# Model Saved!
#
# [ Train epoch: 139 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0003731660544872284
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.001276012510061264
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0010705739259719849
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0009636580944061279
#
# Total benign train accuarcy: 99.98
# Total benign train loss: 0.7039840426295996
#
# [ Test epoch: 139 ]
#
# Test accuarcy: 94.41
# Test average loss: 0.002299258016422391
# Model Saved!
#
# [ Train epoch: 140 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0012878179550170898
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0008157417178153992
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0006951838731765747
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.000497765839099884
#
# Total benign train accuarcy: 99.982
# Total benign train loss: 0.6772328361985274
#
# [ Test epoch: 140 ]
#
# Test accuarcy: 94.59
# Test average loss: 0.0022949808150529863
# Model Saved!
#
# [ Train epoch: 141 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0012011267244815826
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0005974359810352325
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.000531323254108429
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.000644586980342865
#
# Total benign train accuarcy: 99.98
# Total benign train loss: 0.7130141981178895
#
# [ Test epoch: 141 ]
#
# Test accuarcy: 94.64
# Test average loss: 0.0022840436488389968
# Model Saved!
#
# [ Train epoch: 142 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.000569075345993042
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.003083162009716034
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0009224079549312592
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.003042925149202347
#
# Total benign train accuarcy: 99.978
# Total benign train loss: 0.677012755535543
#
# [ Test epoch: 142 ]
#
# Test accuarcy: 94.52
# Test average loss: 0.002288518362864852
# Model Saved!
#
# [ Train epoch: 143 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0005962587893009186
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0016075670719146729
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0016872026026248932
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0011207573115825653
#
# Total benign train accuarcy: 99.992
# Total benign train loss: 0.5609379180241376
#
# [ Test epoch: 143 ]
#
# Test accuarcy: 94.53
# Test average loss: 0.002290073029696941
# Model Saved!
#
# [ Train epoch: 144 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0008281171321868896
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0008774995803833008
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0002883151173591614
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00034762173891067505
#
# Total benign train accuarcy: 99.988
# Total benign train loss: 0.6329321932280436
#
# [ Test epoch: 144 ]
#
# Test accuarcy: 94.51
# Test average loss: 0.002292966876551509
# Model Saved!
#
# [ Train epoch: 145 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.003397531807422638
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0007631964981555939
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0016471631824970245
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0016367100179195404
#
# Total benign train accuarcy: 99.992
# Total benign train loss: 0.5842469729541335
#
# [ Test epoch: 145 ]
#
# Test accuarcy: 94.52
# Test average loss: 0.0022917380549013614
# Model Saved!
#
# [ Train epoch: 146 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.00041010230779647827
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0011134371161460876
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.000762399286031723
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0010400563478469849
#
# Total benign train accuarcy: 99.994
# Total benign train loss: 0.5054906054865569
#
# [ Test epoch: 146 ]
# Test accuarcy: 94.61
# Test average loss: 0.0022983204532414673
# Model Saved!
#
# [ Train epoch: 147 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0012747310101985931
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0014387443661689758
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0003022439777851105
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0013523101806640625
#
# Total benign train accuarcy: 99.988
# Total benign train loss: 0.546846938872477
#
# [ Test epoch: 147 ]
#
# Test accuarcy: 94.65
# Test average loss: 0.0022674564827233554
# Model Saved!
#
# [ Train epoch: 148 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.000661998987197876
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0018216148018836975
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0030073560774326324
#
# Current batch: 300
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0007052198052406311
#
# Total benign train accuarcy: 99.986
# Total benign train loss: 0.5669246096222196
#
# [ Test epoch: 148 ]
#
# Test accuarcy: 94.64
# Test average loss: 0.002270914516970515
# Model Saved!
#
# [ Train epoch: 149 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0011883080005645752
#
# Current batch: 100
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0012230239808559418
#
# Current batch: 200
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0005791187286376953
#
# Current batch: 300
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.012716040015220642
#
# Total benign train accuarcy: 99.984
# Total benign train loss: 0.5817318819463253
#
# [ Test epoch: 149 ]
#
# Test accuarcy: 94.63
# Test average loss: 0.0022760232340544462
# Model Saved!
